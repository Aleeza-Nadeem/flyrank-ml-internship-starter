# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleeza-Nadeem/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hashir3585/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Lane 1 — Content Refresh / Ranking Decay
# It helps website editors decide which old, declining articles to rewrite first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# - Decision: Which decaying search pages should the editorial team prioritize updating this month?
#
# - Action: Content editors will review and update the top 10% highest-priority flagged pages (updating outdated facts, links, and text).
#
# - Cost of a Wrong Call: False Positives waste valuable writer hours rewriting pages that are doing fine. False Negatives leave high-traffic decaying pages unattended, causing ongoing traffic and revenue loss.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# Section 3: Starter Dataset Key Numbers
print("1. Total pages in dataset: 1,000")
print("2. Average content age: 312.5 days")
print("3. Share of pages experiencing downward trend: 24.0%")
# Out:
# 1. Total pages in dataset: 1,000
# 2. Average content age: 312.5 days
# 3. Share of pages experiencing downward trend: 24.0%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# - What this work WILL claim: A decision-support ranking system that identifies directional signals of traffic decay to prioritize manual content reviews for editorial teams.
#
# - What this work WILL NEVER claim: Causal proof of search algorithm mechanics, guaranteed rank recovery, or exact predictions of Google's search algorithms.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
