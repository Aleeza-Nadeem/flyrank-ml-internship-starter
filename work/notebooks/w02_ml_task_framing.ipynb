# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Aleeza-Nadeem/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# - Task Type: Binary Classification / Priority Ranking
#
# - Why: We want to predict whether a URL will experience significant search traffic decay in the next 30 days, ranking URLs by decay risk so content editors can prioritize which pages to update first

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# - Target: is_decaying (Binary flag: 1 if clicks/impressions drop by $\ge$ 20% in the following time window, 0 otherwise).
#
# - Label Source: Observed outcome from performance data across adjacent time windows (an observed metric rather than a manually defined rule).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# - Primary Metric: Precision@50
#
# - What means 'good': Precision@50 $> 0.80$. Since content teams have limited time each month, a high Precision@50 ensures that at least 80% of the top 50 flagged pages are actually declining and worth their time to rewrite.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Unit of Analysis: 1 Row = 1 Unique URL
data = {
    "url": ["/blog/python-guide", "/blog/seo-tips", "/blog/ml-intro"],
    "content_age_days": [420, 150, 600],
    "avg_position": [4.2, 12.1, 2.5],
    "ctr": [0.035, 0.012, 0.058],
    "is_decaying": [1, 0, 1]  # Target column
}

df = pd.DataFrame(data)
print("Unit of Analysis: 1 Row = 1 Unique URL")
df.head()
# Out:
# Unit of Analysis: 1 Row = 1 Unique URL
#                   url  content_age_days  avg_position    ctr  is_decaying
# 0  /blog/python-guide               420           4.2  0.035            1
# 1      /blog/seo-tips               150          12.1  0.012            0
# 2      /blog/ml-intro               600           2.5  0.058            1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# - Text: Simple if/else rules like if age > 300 days perform poorly because evergreen content can stay relevant for years while news topics decay rapidly. Machine learning captures non-linear interactions between page age, position drops, and search volume shifts that static rules miss.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
